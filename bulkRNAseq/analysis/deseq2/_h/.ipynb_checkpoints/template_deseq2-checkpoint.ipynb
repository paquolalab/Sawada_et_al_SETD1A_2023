# %% [markdown]
# ## Set Up packages

# %%
if(!require("tidyverse")) 
    install.packages("tidyverse")
# install.packages("GenomicFeatures") 

library(tidyverse)
## library(GenomicFeatures)
# Out:
# Loading required package: tidyverse
#
# -- Attaching packages --------------------------------------- tidyverse 1.3.2 --
# v ggplot2 3.4.0      v purrr   0.3.4
# v tibble  3.1.8      v dplyr   1.0.10
# v tidyr   1.2.0      v stringr 1.4.0
# v readr   2.1.2      v forcats 0.5.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
if (!require("BiocManager", quietly = TRUE))
    suppressMessages(install.packages("BiocManager"))

if(!require(DESeq2))
    suppressMessages(BiocManager::install("DESeq2"))
suppressMessages(library(DESeq2))
    
if(!require(GenomicFeatures))
    suppressMessages(BiocManager::install("GenomicFeatures"))
suppressMessages(library(GenomicFeatures))
# Out:
# Bioconductor version '3.14' is out-of-date; the current release version '3.16'
#   is available with R version '4.2'; see https://bioconductor.org/install
#
# Loading required package: DESeq2
#
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:dplyr':
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
# ...

# %%
if(!require(SummarizedExperiment))
   BiocManager::install("SummarizedExperiment")
library(SummarizedExperiment)

# %%
#sessionInfo()

# %%
if(!require(openxlsx))
    install.packages('openxlsx')
library(openxlsx)
# Out:
# Loading required package: openxlsx

# %%
if(!require(openxlsx))
    install.packages('data.table')
library(openxlsx)

# %%
if (!require(devtools)) install.packages("devtools")
devtools::install_github("yanlinlin82/ggvenn")
# Out:
# Loading required package: devtools
#
# Loading required package: usethis
#
#
# Attaching package: 'devtools'
#
#
# The following object is masked from 'package:BiocManager':
#
#     install
#
#
# Skipping install of 'ggvenn' from a github remote, the SHA1 (306a3302) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
library(ggvenn)
# Out:
# Loading required package: grid

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Import Metadata

# %%
metaData <- read.xlsx('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/Meta_sample_info/041221_SETD1A_bulk_RNAseq_Metadata.xlsx', colNames=TRUE, startRow = 4)
#Arthur's Data          ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/Meta_sample_info/041221_SETD1A_bulk_RNAseq_Metadata.xlsx

head(metaData)
#Why did Arthur remove row 5 from the metadata? If I do that as well, now all the dimensions match for the Summarized Experiment Object
metaData <- metaData[-5, -1]

head(metaData)
dim(metaData)
#tail(metaData)
# Out:
#   # Sample.ID               New.Sample.ID            Brain.number iPSC.line
# 1 1 LIBD2c1_CA137_11_CO_d12 LIBD2c1_CA137_#11_CO_d12 Br2371       LIBD2c1
# 2 2 LIBD2c1_CM130_9_CO_d12  LIBD2c1_CM130_#9_CO_d12  Br2371       LIBD2c1
# 3 3 LIBD2c1_CM130_24_CO_d12 LIBD2c1_CM130_#24_CO_d12 Br2371       LIBD2c1
# 4 4 LIBD2c1_CM130_21_CO_d12 LIBD2c1_CM130_#21_CO_d12 Br2371       LIBD2c1
# 5 5 LIBD2c1_CM130_51_CO_d12 LIBD2c1_CM130_#51_CO_d12 Br2371       LIBD2c1
# 6 6 LIBD7c6_CA137_37_CO_d12 LIBD7c6_CA137_#37_CO_d12 Br5287       LIBD7c6
#   iPSC.clone RIN  Sample.type       Day Passage <U+22EF>   Comparison-36
# 1 CA137_#11   9.7 Cerebral organoid 12  n/a     <U+22EF> NA
# 2 CM130_#9    9.5 Cerebral organoid 12  n/a     <U+22EF> NA
# 3 CM130_#24  10.0 Cerebral organoid 12  n/a     <U+22EF> NA
# 4 CM130_#21  10.0 Cerebral organoid 12  n/a     <U+22EF> NA
# 5 CM130_#51  10.0 Cerebral organoid 12  n/a     <U+22EF> NA
# 6 CA137_#37  10.0 Cerebral organoid 12  n/a     <U+22EF> NA
# ...

# %%
row.names(metaData) <- metaData$Sample.ID
#head(metaData)
#dim(metaData)

# %% [markdown]
# ### Import Gene Counts

# %%
geneCounts <- as.data.frame(read_tsv("/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/fastq/hisat2/featurecounts_genes_M/count_table/_m/counts.tsv", col_names = TRUE)) #read_tsv imported the data as a tibble, so I'll change that to 
#Arthur's Data            read.delim('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/fastq/hisat2/featurecounts_genes_M/count_table/_m/counts.tsv')  
#a dataframe for easier use
head(geneCounts) #checking import
dim(geneCounts)
# Out:
# Rows: 60710 Columns: 39
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr  (1): Geneid
# dbl (38): LIBD2c1_CA137_11_CO_d12, LIBD2c1_CA137_11_CO_d48, LIBD2c1_CM130_21...
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Geneid            LIBD2c1_CA137_11_CO_d12 LIBD2c1_CA137_11_CO_d48
# 1 ENSG00000223972.5  11                       3
# 2 ENSG00000227232.5 450                     309
# 3 ENSG00000278267.1  22                       7
# 4 ENSG00000243485.5   6                       7
# 5 ENSG00000284332.1   0                       0
# 6 ENSG00000237613.2   2                       0
#   LIBD2c1_CM130_21_CO_d12 LIBD2c1_CM130_21_CO_d48 LIBD2c1_CM130_21_Neuron_4wks
# 1   1                       1                       4
# 2 331                     405                     464
# ...

# %%
#To make the SummarizedExperiment object later, I need to have rownames corresponding to the geneIDs. Since 'Geneid' is the first column, I'll use those values
#to define the rownames and then remove that column from the dataframe
row.names(geneCounts) = geneCounts$Geneid
geneCounts <- geneCounts[,-1]

# %%
head(geneCounts) #checking the reformatting
dim(geneCounts)
# Out:
#                   LIBD2c1_CA137_11_CO_d12 LIBD2c1_CA137_11_CO_d48
# ENSG00000223972.5  11                       3
# ENSG00000227232.5 450                     309
# ENSG00000278267.1  22                       7
# ENSG00000243485.5   6                       7
# ENSG00000284332.1   0                       0
# ENSG00000237613.2   2                       0
#                   LIBD2c1_CM130_21_CO_d12 LIBD2c1_CM130_21_CO_d48
# ENSG00000223972.5   1                       1
# ENSG00000227232.5 331                     405
# ENSG00000278267.1  19                      11
# ENSG00000243485.5   8                      13
# ENSG00000284332.1   0                       0
# ENSG00000237613.2   0                       0
#                   LIBD2c1_CM130_21_Neuron_4wks LIBD2c1_CM130_21_NPC
# ENSG00000223972.5   4                            2
# ENSG00000227232.5 464                          317
# ENSG00000278267.1   9                           16
# ENSG00000243485.5   5                            9
# ...

# %%
# Arthur subset the readcounts to match the order of the metadata file

geneCounts <- geneCounts[row.names(metaData)]
head(geneCounts)
dim(geneCounts)
# Out:
#                   LIBD2c1_CA137_11_CO_d12 LIBD2c1_CM130_9_CO_d12
# ENSG00000223972.5  11                       1
# ENSG00000227232.5 450                     212
# ENSG00000278267.1  22                       9
# ENSG00000243485.5   6                       1
# ENSG00000284332.1   0                       0
# ENSG00000237613.2   2                       0
#                   LIBD2c1_CM130_24_CO_d12 LIBD2c1_CM130_21_CO_d12
# ENSG00000223972.5   5                       1
# ENSG00000227232.5 235                     331
# ENSG00000278267.1   8                      19
# ENSG00000243485.5  14                       8
# ENSG00000284332.1   0                       0
# ENSG00000237613.2   0                       0
#                   LIBD7c6_CA137_37_CO_d12 LIBD7c6_CA137_109_CO_d12
# ENSG00000223972.5   0                       1
# ENSG00000227232.5 308                     235
# ENSG00000278267.1  14                      15
# ENSG00000243485.5  10                       6
# ...

# %%
# I also need to import the gene lengths, since that will go into the rowData aspect of the se object.

geneLengths <- as.data.frame(read_tsv("/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/fastq/hisat2/featurecounts_genes/count_table/_m/lengths.tsv"))
head(geneLengths)
# Out:
# Rows: 60710 Columns: 2
# -- Column specification --------------------------------------------------------
# Delimiter: "\t"
# chr (1): Geneid
# dbl (1): Length
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Geneid            Length
# 1 ENSG00000223972.5 1735
# 2 ENSG00000227232.5 1351
# 3 ENSG00000278267.1   68
# 4 ENSG00000243485.5 1021
# 5 ENSG00000284332.1  138
# 6 ENSG00000237613.2 1219

# %%
#Make the Geneid column into the rownames for this data frame as well. Then the se object should be able to match the rownames in the counts data table with row names of the gene lengths table.
row.names(geneLengths) = geneLengths$Geneid
geneLengths <- geneLengths[,-1]

# %% [markdown]
# ### Make Summarized Experiment Object

# %%
se <- SummarizedExperiment(assays = list(counts=as.matrix(geneCounts)), rowData=geneLengths, colData = metaData)
se
# Out:
# class: SummarizedExperiment
# dim: 60710 37
# metadata(0):
# assays(1): counts
# rownames(60710): ENSG00000223972.5 ENSG00000227232.5 ...
#   ENSG00000278625.1 ENSG00000277374.1
# rowData names(1): X
# colnames(37): LIBD2c1_CA137_11_CO_d12 LIBD2c1_CM130_9_CO_d12 ...
#   LIBD7c6_CM130_30_Neuron_4wks LIBD7c6_CM130_78_Neuron_4wks
# colData names(59): Sample.ID New.Sample.ID ... Comparison-44
#   Comparison-45

# %%
#Checking the count data
#head(assay(se))

# %%
#Changing the name of the column
#rowData(se)

# %%
#Checking row data 
colnames(rowData(se)) = "Length"

# %%
#Changing the name of the column
#rowData(se)

# %%
#Checking the column data aspect of the se
#head(colData(se))

# %%
table(se$Sample.type)
# Out:
# Cerebral organoid               NPC            Neuron
#                23                 8                 6

# %%
table(se$'Comparison-31')
# Out:
# mut  wt
#   5   3

# %%
table(se$'Comparison-40')
# Out:
# mut  wt
#   3   3

# %%
# This SummarizedExperiment (se) now has all the metadata about all the experiments as well as all the count data. To subset to just the data used in the SETD1a paper, we need to reduce to just the samples used in 
# Comparison-31 and Comparison-40. We also need to remove sample Sample_ID != 'LIBD2c1_CM130_51_NPC' since that was removed in the subset data as well
#Since Comparison 31 was all the NPCs and Comparison 40 was all the Neurons, the only other sample type was Cerebral organoid, so I can just exclude those samples.

#se_3140 <- se[, se$Sample.type !="Cerebral organoid"]
#se_3140 <- se_3140[, se_3140$Sample.ID !="LIBD2c1_CM130_51_NPC"]
#se_3140

#I realized that I misunderstood the fundamental experimental design, so there should be two SE objects: one for comparison 31, and a second for comparison-40. They are supposed to be separate, not combined
se_31 <- se[ , se$Sample.type == "NPC"]
se_31 <- se_31[, se_31$Sample.ID != "LIBD2c1_CM130_51_NPC"]
se_40 <- se[ , se$Sample.type == "Neuron"]
print("Comparison 31")
head(se_31)
print("Comparison 40")
head(se_40)

#These will be the se objects used for all future analyses/comparisons
# Out:
# [1] "Comparison 31"
# class: SummarizedExperiment
# dim: 6 7
# metadata(0):
# assays(1): counts
# rownames(6): ENSG00000223972.5 ENSG00000227232.5 ... ENSG00000284332.1
#   ENSG00000237613.2
# rowData names(1): Length
# colnames(7): LIBD2c1_CM130_24_NPC LIBD2c1_CM130_21_NPC ...
#   LIBD7c6_CM130_42_NPC LIBD7c6_CM130_78_NPC
# colData names(59): Sample.ID New.Sample.ID ... Comparison-44
#   Comparison-45
# [1] "Comparison 40"
# class: SummarizedExperiment
# dim: 6 6
# metadata(0):
# assays(1): counts
# rownames(6): ENSG00000223972.5 ENSG00000227232.5 ... ENSG00000284332.1
#   ENSG00000237613.2
# rowData names(1): Length
# colnames(6): LIBD2c1_CM130_24_Neuron_4wks LIBD2c1_CM130_21_Neuron_4wks
#   ... LIBD7c6_CM130_30_Neuron_4wks LIBD7c6_CM130_78_Neuron_4wks
# colData names(59): Sample.ID New.Sample.ID ... Comparison-44
#   Comparison-45

# %% [markdown]
# ## DESeq2 Analysis

# %%
#dds <- DESeqDataSet(se_3140, ~ Genotype-1)

#This yields an error saying the design formula isn't specifying a column in the colData. I'm not sure if that is because of the hyphen or because this 
# is a SummarizedExperiments object rather than the RangedSummarizedExperiments object (a subset of the SE object class - the main difference is that 
#the RSE object includes the genomic ranges of the genes in the count table. Since I didn't get the data from the bam files, I just have the counts
# information and the lengths of each gene. To work around this, I am going to try to build a DESeq object directly from my input matrices.

##Update: Other factors in the design work just fine, so it is the hyphen. I think the design value is trying to interpret a minus sign and "Genotype" 
#instead of "Genotype-1". And "Genotype isn't a column name, so I get the error message. To work around that, I just need to change that column name

# %%
#colnames(colData(se_3140))
#colnames(colData(se_3140))[colnames(colData(se_3140))=="Genotype-1"] <- 'Genotype_1'
#colnames(colData(se_3140))

tail(colnames(colData(se_31)))
colnames(colData(se_31)) <- gsub("-", "_", colnames(colData(se_31)))
tail(colnames(colData(se_31)))
# Out:
# [1] "Comparison-40" "Comparison-41" "Comparison-42" "Comparison-43"
# [5] "Comparison-44" "Comparison-45"
# [1] "Comparison_40" "Comparison_41" "Comparison_42" "Comparison_43"
# [5] "Comparison_44" "Comparison_45"

# %%
tail(colnames(colData(se_40)))
colnames(colData(se_40)) <- gsub("-", "_", colnames(colData(se_40)))
tail(colnames(colData(se_40)))
#This just changed the column names to remove any hyphens that will mess up downstream name calling
# Out:
# [1] "Comparison_40" "Comparison_41" "Comparison_42" "Comparison_43"
# [5] "Comparison_44" "Comparison_45"
# [1] "Comparison_40" "Comparison_41" "Comparison_42" "Comparison_43"
# [5] "Comparison_44" "Comparison_45"

# %%
#Artur also told me that in his model, he included iPSC cell line as a batch variable to control for when doing the DESeq design model.

#dds <- DESeqDataSet(se_3140, ~iPSC.line + Genotype_1)
#dds

dds31 <- DESeqDataSet(se_31, ~iPSC.line + Genotype_1)
dds40 <- DESeqDataSet(se_40, ~iPSC.line + Genotype_1)

print("dds31")
dds31

print("dds40")
dds40

#Successful creation of DESeq Data Object
# Out:
# converting counts to integer mode
#
# Warning message in DESeqDataSet(se_31, ~iPSC.line + Genotype_1):
# "some variables in design formula are characters, converting to factors"
# converting counts to integer mode
#
# Warning message in DESeqDataSet(se_40, ~iPSC.line + Genotype_1):
# "some variables in design formula are characters, converting to factors"
# [1] "dds31"
# class: DESeqDataSet
# dim: 60710 7
# metadata(1): version
# assays(1): counts
# rownames(60710): ENSG00000223972.5 ENSG00000227232.5 ...
#   ENSG00000278625.1 ENSG00000277374.1
# rowData names(1): Length
# colnames(7): LIBD2c1_CM130_24_NPC LIBD2c1_CM130_21_NPC ...
#   LIBD7c6_CM130_42_NPC LIBD7c6_CM130_78_NPC
# colData names(59): Sample.ID New.Sample.ID ... Comparison_44
#   Comparison_45
# [1] "dds40"
# class: DESeqDataSet
# dim: 60710 6
# metadata(1): version
# assays(1): counts
# rownames(60710): ENSG00000223972.5 ENSG00000227232.5 ...
#   ENSG00000278625.1 ENSG00000277374.1
# rowData names(1): Length
# ...

# %%
#dds$Genotype_1
dds31$Genotype_1
dds40$Genotype_1
# Out:
# [1] wt  mut wt  mut mut mut wt
# Levels: mut wt
# [1] wt  mut wt  mut mut wt
# Levels: mut wt

# %%
#Relevelling dds31 so that wt is the comparison group

levels(dds31$Genotype_1)
dds31$Genotype_1 <- relevel(dds31$Genotype_1, "wt")
levels(dds31$Genotype_1)
# Out:
# [1] "mut" "wt"
# [1] "wt"  "mut"

# %%
#Releveling dds40 so that wt is the comparison group

levels(dds40$Genotype_1)
dds40$Genotype_1 <- relevel(dds40$Genotype_1, "wt")
levels(dds40$Genotype_1)
# Out:
# [1] "mut" "wt"
# [1] "wt"  "mut"

# %%
#Removing genes with less than 5 counts for all samples and Estimating Size Factors. 5 was a cutoff picked previously in the lab, so Arthur used it for his analysis

expressedGenes31 <- rowSums(counts(dds31)) >=5 
expressedGenes40 <- rowSums(counts(dds40)) >=5 

dds31 <- estimateSizeFactors(dds31)
dds40 <- estimateSizeFactors(dds40)

dds31 <- dds31[expressedGenes31, ]
dds40 <- dds40[expressedGenes40, ]

dds31
dds40
# Out:
# class: DESeqDataSet
# dim: 28287 7
# metadata(1): version
# assays(1): counts
# rownames(28287): ENSG00000223972.5 ENSG00000227232.5 ...
#   ENSG00000278817.1 ENSG00000277196.4
# rowData names(1): Length
# colnames(7): LIBD2c1_CM130_24_NPC LIBD2c1_CM130_21_NPC ...
#   LIBD7c6_CM130_42_NPC LIBD7c6_CM130_78_NPC
# colData names(60): Sample.ID New.Sample.ID ... Comparison_45 sizeFactor
# class: DESeqDataSet
# dim: 27898 6
# metadata(1): version
# assays(1): counts
# rownames(27898): ENSG00000223972.5 ENSG00000227232.5 ...
#   ENSG00000278817.1 ENSG00000277196.4
# rowData names(1): Length
# colnames(6): LIBD2c1_CM130_24_Neuron_4wks LIBD2c1_CM130_21_Neuron_4wks
#   ... LIBD7c6_CM130_30_Neuron_4wks LIBD7c6_CM130_78_Neuron_4wks
# colData names(60): Sample.ID New.Sample.ID ... Comparison_45 sizeFactor

# %%
#It looks like that removed about the same number of genes from both analyses, but slightly more from the Comparison_40.

#Double checking the model
#design(dds)

design(dds31)
design(dds40)
# Out:
# ~iPSC.line + Genotype_1
# ~iPSC.line + Genotype_1

# %% [markdown]
# ## Running DESeq Analysis and Creating res__ objects

# %%
#Those both look good, so now we can run the DESeq analysis

#Now we can run the DESeq analysis

#dds <- DESeq(dds)

dds31 <- DESeq(dds31)
# Out:
# using pre-existing size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing

# %%
res31 <- lfcShrink(dds31, coef=paste0(resultsNames(dds31)[length(resultsNames(dds31))]),type='apeglm')
# From Arthur's analysis: res <- lfcShrink(dds, coef=paste0(resultsNames(dds31)[length(resultsNames(dds31))]),type='apeglm')
# Out:
# using 'apeglm' for LFC shrinkage. If used in published research, please cite:
#     Zhu, A., Ibrahim, J.G., Love, M.I. (2018) Heavy-tailed prior distributions for
#     sequence count data: removing the noise and preserving large differences.
#     Bioinformatics. https://doi.org/10.1093/bioinformatics/bty895

# %%
dds40 <- DESeq(dds40)
res40 <- lfcShrink(dds40, coef=paste0(resultsNames(dds40)[length(resultsNames(dds40))]),type='apeglm')
# Out:
# using pre-existing size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# using 'apeglm' for LFC shrinkage. If used in published research, please cite:
#     Zhu, A., Ibrahim, J.G., Love, M.I. (2018) Heavy-tailed prior distributions for
#     sequence count data: removing the noise and preserving large differences.
#     Bioinformatics. https://doi.org/10.1093/bioinformatics/bty895

# %%
res40
# Out:
# log2 fold change (MAP): Genotype 1 mut vs wt
# Wald test p-value: Genotype 1 mut vs wt
# DataFrame with 27898 rows and 5 columns
#                     baseMean log2FoldChange     lfcSE    pvalue      padj
#                    <numeric>      <numeric> <numeric> <numeric> <numeric>
# ENSG00000223972.5   0.910554    0.000414733 0.0417338  0.568010        NA
# ENSG00000227232.5 340.478818   -0.002485734 0.0410702  0.749263  0.971435
# ENSG00000278267.1   9.870827   -0.000782933 0.0416848  0.725252        NA
# ENSG00000243485.5   5.166706   -0.001715944 0.0417539  0.292336        NA
# ENSG00000238009.6   2.515582   -0.000309897 0.0417200  0.769556        NA
# ...                      ...            ...       ...       ...       ...
# ENSG00000276700.1  107.10621    -0.00416580 0.0418866 0.2261156  0.846660
# ENSG00000275757.1  111.22713    -0.00696425 0.0424047 0.0804742  0.695903
# ENSG00000278573.1    2.31711     0.00113211 0.0417399 0.3391817        NA
# ...

# %%
print("res31")
res31
# Out:
# [1] "res31"
# log2 fold change (MAP): Genotype 1 mut vs wt
# Wald test p-value: Genotype 1 mut vs wt
# DataFrame with 28287 rows and 5 columns
#                     baseMean log2FoldChange     lfcSE    pvalue      padj
#                    <numeric>      <numeric> <numeric> <numeric> <numeric>
# ENSG00000223972.5   0.666747   -0.000403197  0.131525  0.937795        NA
# ENSG00000227232.5 250.022350    0.010532665  0.113555  0.858296  0.983470
# ENSG00000278267.1  13.602313   -0.004097647  0.128865  0.876877  0.986916
# ENSG00000243485.5   4.140557    0.012959702  0.131424  0.461066        NA
# ENSG00000238009.6   2.881767   -0.005903300  0.130944  0.709494        NA
# ...                      ...            ...       ...       ...       ...
# ENSG00000276312.1   0.707429     0.00221523  0.131604  0.648147        NA
# ENSG00000275757.1 127.430873    -0.01632127  0.121568  0.738479  0.964319
# ENSG00000278573.1   2.585744     0.00672891  0.131154  0.630085        NA
# ...

# %%
cat("res40")
res40
# Out:
# res40
# log2 fold change (MAP): Genotype 1 mut vs wt
# Wald test p-value: Genotype 1 mut vs wt
# DataFrame with 27898 rows and 5 columns
#                     baseMean log2FoldChange     lfcSE    pvalue      padj
#                    <numeric>      <numeric> <numeric> <numeric> <numeric>
# ENSG00000223972.5   0.910554    0.000414733 0.0417338  0.568010        NA
# ENSG00000227232.5 340.478818   -0.002485734 0.0410702  0.749263  0.971435
# ENSG00000278267.1   9.870827   -0.000782933 0.0416848  0.725252        NA
# ENSG00000243485.5   5.166706   -0.001715944 0.0417539  0.292336        NA
# ENSG00000238009.6   2.515582   -0.000309897 0.0417200  0.769556        NA
# ...                      ...            ...       ...       ...       ...
# ENSG00000276700.1  107.10621    -0.00416580 0.0418866 0.2261156  0.846660
# ENSG00000275757.1  111.22713    -0.00696425 0.0424047 0.0804742  0.695903
# ENSG00000278573.1    2.31711     0.00113211 0.0417399 0.3391817        NA
# ...

# %%
#Checking the MA plots of the analysis

DESeq2::plotMA(res31)
#plotMA(res40)
# Out:
# Plot with title ""

# %%
DESeq2::plotMA(res31)
#plotMA(res31)
# Out:
# Plot with title ""

# %%
DESeq2::plotMA(res40, alpha=0.01)
#plotMA(res40)
# Out:
# Plot with title ""

# %%
#Checking Dispersion Esimate Plots

plotDispEsts(dds31)
plotDispEsts(dds40)
# Out:
# plot without title
# plot without title

# %%
#Checking the smallest p-value count values
#counts(dds)[which.min(res$pvalue), ]

# %%
#Or we can check the normalized counts
#counts(dds, normalized = TRUE)[which.min(res$pvalue), ]

# %%
#To extract the results, a tutorial shows we can use the contrast argument in the results function
#log2changes <- results(dds, contrast = c("Genotype_1", "wt", "mut")) #For future reference, the wt and mut should be switched in this command. As written, it gives the results for a wt compared to mut-baseline
#log2changes


#This is now a results table outside of the large DESeq object

# %%
#To switch from the Ensembl gene IDs to common gene names, there is a package from Bioconductor provided with the following code:

#library("org.Hs.eg.db")
#columns(org.Hs.eg.db)
#This is a list of all the available gene naming schemes it can convert between. This is super useful

# %%
## A convenience function provided with the package to enable easy gene ID conversion. This creates a new function (convertIDs) that does the conversion between different gene database names

#ids = list of IDS
#fromKey = key type; toKey = key type we want to convert to
#db = the AnnotationDb object to use.
#ifMultiple = the argument specifies what to do if one source ID maps to several target IDs:
  #should the function return an NA or simply the first of the multiple IDs?
# convertIDs <- function( ids, fromKey, toKey, db, ifMultiple=c( "putNA", "useFirst" ) ) {
#    stopifnot( inherits( db, "AnnotationDb" ) )
#    ifMultiple <- match.arg( ifMultiple )
#    suppressWarnings( selRes <- AnnotationDbi::select( 
#       db, keys=ids, keytype=fromKey, columns=c(fromKey,toKey) ) )
#    if( ifMultiple == "putNA" ) {
#       duplicatedIds <- selRes[ duplicated( selRes[,1] ), 1 ]   
#       selRes <- selRes[ ! selRes[,1] %in% duplicatedIds, ] }
#    return( selRes[ match( ids, selRes[,1] ), 2 ] )
# }

# %%
#To convert our list of gene names 

## I'm not sure why this chunk isn't working. Maybe it's because there is a decimal after the main ensemble id specifying the transcript? I'm not sure. I need to come back to this later

#log2changes$hgnc_symbol <- convertIDs(row.names(log2changes), "ENSEMBLTRANS", "SYMBOL", org.Hs.eg.db )
#log2changes$entrezid <- convertIDs( row.names(log2changes), "ENSEMBL", "ENTREZID", org.Hs.eg.db )
#head(log2changes, 5)

# %%
#That gave an error. I'm wondering if it's because the ENSEMBL IDs have the decimals specifying which transcript, so I need a different conversion list

# %%
#key(org.Hs.eg.db, "ENSEMBL")

# %%
#is.vector(row.names(log2changes))

# %% [markdown]
# ## Arthur's Analysis

# %%
options(stringsAsFactors = F)

suppressMessages(library(SummarizedExperiment))
suppressMessages(library(DESeq2))
if(!require(calibrate))
    BiocManager::install("calibrate")
suppressMessages(library(calibrate))
if(!require("ggplot2")) 
    install.packages("ggplot2")
suppressMessages(library(ggplot2))
if(!require(edgeR))
    BiocManager::install("edgeR")
suppressMessages(library(edgeR))
if(!require(sva))
    BiocManager::install("sva")
suppressMessages(library(sva))
if(!require(stringr))
    BiocManager::install("stringr")
suppressMessages(library(stringr))
if(!require("readxl")) 
    install.packages("readxl")
suppressMessages(library(readxl))
if(!require("reshape2")) 
    install.packages("reshape2")
suppressMessages(library(reshape2))
if(!require("dplyr")) 
    install.packages("dplyr")
suppressMessages(library(dplyr))
if(!require(ReportingTools))
    BiocManager::install("ReportingTools")
suppressMessages(library(ReportingTools))
if(!require("tidyverse")) 
    install.packages("tidyverse")
suppressMessages(library(tidyverse))
if(!require(data.table))
    BiocManager::install("data.table")
suppressMessages(library(data.table))
if(!require(EnhancedVolcano))
    BiocManager::install("EnhancedVolcano")
suppressMessages(library(EnhancedVolcano))

library(sessioninfo)


options(repr.plot.width=8, repr.plot.height=8)
# Out:
# Loading required package: calibrate
#
# Loading required package: MASS
#
#
# Attaching package: 'MASS'
#
#
# The following object is masked from 'package:AnnotationDbi':
#
#     select
#
#
# The following object is masked from 'package:dplyr':
#
#     select
#
#
# Loading required package: edgeR
#
# Loading required package: limma
#
#
# Attaching package: 'limma'
#
#
# The following object is masked from 'package:DESeq2':
#
#     plotMA
#
#
# The following object is masked from 'package:BiocGenerics':
#
#     plotMA
#
#
# Loading required package: sva
#
# Loading required package: mgcv
#
# Loading required package: nlme
#
#
# Attaching package: 'nlme'
#
#
# The following object is masked from 'package:IRanges':
#
#     collapse
#
#
# The following object is masked from 'package:dplyr':
#
#     collapse
#
#
# This is mgcv 1.8-40. For overview type 'help("mgcv-package")'.
#
# Loading required package: genefilter
#
#
# Attaching package: 'genefilter'
#
#
# ...

# %%
if(!require(apeglm))
    BiocManager::install("apeglm")
library(apeglm)
# Out:
# Loading required package: apeglm

# %%
# for now, remove sample LIBD2c1_CM130_51_NPC ##Hunter's Comment: Why is this one removed?

# %% [markdown]
# ## Read limma-voom Metadata file

# %%
# metadata <- read_xlsx('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/Meta_sample_info/041221_SETD1A_bulk_RNAseq_Metadata.xlsx',skip=3,na = 'n/a')
# metadata <- metadata[-5,]
# head(metadata)
# dim(metadata)

# %%
metadata <- read_xlsx('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/Meta_sample_info/041221_SETD1A_bulk_RNAseq_Metadata.xlsx',skip=3,na = 'n/a')
metadata <- as.data.frame(metadata[-5,-1])
metadata <- as.data.frame(metadata)
names(metadata) <- gsub(' |-', '_',names(metadata)) #Replaces all hyphens with underscores
metadata$Sample_type <- gsub('Cerebral organoid','CO',metadata$Sample_type) #changes all sample types from "Cerebral Organoid" to "CO"
row.names(metadata) <- metadata$Sample_ID #Makes the sample ID the rownames
metadata <- metadata #I'm not sure what this does... It looks like it assigns a variable to itself
colnames(metadata)[14] <- 'Comparison_0'

#colnames(metadata)[ncol(metadata)] <- 'Big_Model'
metadata[is.na(metadata)] <- 'NA' #change all numeric NA values for a character 'NA' value
#metadata

dim(metadata)
head(metadata)
#tail(metadata)
# Out:
# [1] 37 59
#                          Sample_ID                New_Sample_ID
# LIBD2c1_CA137_11_CO_d12  LIBD2c1_CA137_11_CO_d12  LIBD2c1_CA137_#11_CO_d12
# LIBD2c1_CM130_9_CO_d12   LIBD2c1_CM130_9_CO_d12   LIBD2c1_CM130_#9_CO_d12
# LIBD2c1_CM130_24_CO_d12  LIBD2c1_CM130_24_CO_d12  LIBD2c1_CM130_#24_CO_d12
# LIBD2c1_CM130_21_CO_d12  LIBD2c1_CM130_21_CO_d12  LIBD2c1_CM130_#21_CO_d12
# LIBD7c6_CA137_37_CO_d12  LIBD7c6_CA137_37_CO_d12  LIBD7c6_CA137_#37_CO_d12
# LIBD7c6_CA137_109_CO_d12 LIBD7c6_CA137_109_CO_d12 LIBD7c6_CA137_#109_CO_d12
#                          Brain_number iPSC_line iPSC_clone RIN  Sample_type Day
# LIBD2c1_CA137_11_CO_d12  Br2371       LIBD2c1   CA137_#11   9.7 CO          12
# LIBD2c1_CM130_9_CO_d12   Br2371       LIBD2c1   CM130_#9    9.5 CO          12
# LIBD2c1_CM130_24_CO_d12  Br2371       LIBD2c1   CM130_#24  10.0 CO          12
# LIBD2c1_CM130_21_CO_d12  Br2371       LIBD2c1   CM130_#21  10.0 CO          12
# ...

# %%
#colnames(metadata[14])

# %%
# metadata_full <- read.csv('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/analysis/limmavoom/metadata/_m/metadata_full.csv')
# head(metadata_full)
# tail(metadata_full)

# %%
metadata_full <- read.csv('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/analysis/limmavoom/metadata/_m/metadata_full-de_design.csv') %>%
    filter(DE_Analysis == 'Comparison_31' | DE_Analysis == 'Comparison_40') %>%
    filter(Sample_ID != 'LIBD2c1_CM130_51_NPC')

metadata_full$design2 <- gsub('Comparison.*','Genotype_1',metadata_full$design)

metadata_full
#tail(metadata_full)
# Out:
#    DE_Analysis   Sample_ID                     New_Sample_ID
# 1  Comparison_31 LIBD7c6_CM130_78_NPC          LIBD7c6_CM130_#78_NPC
# 2  Comparison_31 LIBD7c6_CM130_42_NPC          LIBD7c6_CM130_#42_NPC
# 3  Comparison_31 LIBD7c6_CM130_30_NPC          LIBD7c6_CM130_#30_NPC
# 4  Comparison_31 LIBD7c6_CA137_69_NPC          LIBD7c6_CA137_#69_NPC
# 5  Comparison_31 LIBD7c6_CA137_109_NPC         LIBD7c6_CA137_#109_NPC
# 6  Comparison_31 LIBD2c1_CM130_21_NPC          LIBD2c1_CM130_#21_NPC
# 7  Comparison_31 LIBD2c1_CM130_24_NPC          LIBD2c1_CM130_#24_NPC
# 8  Comparison_40 LIBD7c6_CM130_78_Neuron_4wks  LIBD7c6_CM130_#78_Neuron_4wks
# 9  Comparison_40 LIBD7c6_CM130_30_Neuron_4wks  LIBD7c6_CM130_#30_Neuron_4wks
# 10 Comparison_40 LIBD7c6_CA137_69_Neuron_4wks  LIBD7c6_CA137_#69_Neuron_4wks
# 11 Comparison_40 LIBD7c6_CA137_109_Neuron_4wks LIBD7c6_CA137_#109_Neuron_4wks
# 12 Comparison_40 LIBD2c1_CM130_21_Neuron_4wks  LIBD2c1_CM130_#21_Neuron_4wks
# ...

# %%
#metadata_full$DE_Analysis[1:38]

# %%
metadata_full_comp <- metadata_full[!duplicated(metadata_full$DE_Analysis),]
comparisons <- metadata_full$DE_Analysis[!duplicated(metadata_full$DE_Analysis)]
head(metadata_full_comp)
tail(metadata_full_comp)
dim(metadata_full_comp)
# Out:
#   DE_Analysis   Sample_ID                    New_Sample_ID
# 1 Comparison_31 LIBD7c6_CM130_78_NPC         LIBD7c6_CM130_#78_NPC
# 8 Comparison_40 LIBD7c6_CM130_78_Neuron_4wks LIBD7c6_CM130_#78_Neuron_4wks
#   Brain_number iPSC_line iPSC_clone RIN  Sample_type Day Passage
# 1 Br5287       LIBD7c6   CM130_#78  10.0 NPC         0   4
# 8 Br5287       LIBD7c6   CM130_#78   9.2 Neuron      0   5
#   Patient_mutation Genotype_1 Genotype_2 Genotype_3 design
# 1 NA               wt         wt         wt         ~iPSC_line+Comparison_31
# 8 NA               wt         wt         wt         ~iPSC_line+Comparison_40
#   design2
# 1 ~iPSC_line+Genotype_1
# 8 ~iPSC_line+Genotype_1
#   DE_Analysis   Sample_ID                    New_Sample_ID
# 1 Comparison_31 LIBD7c6_CM130_78_NPC         LIBD7c6_CM130_#78_NPC
# 8 Comparison_40 LIBD7c6_CM130_78_Neuron_4wks LIBD7c6_CM130_#78_Neuron_4wks
#   Brain_number iPSC_line iPSC_clone RIN  Sample_type Day Passage
# ...

# %%
annotation <- read.delim('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/analysis/annotation/_m/annotation_gene-unique-info.tsv')
annotation <- annotation[,c(7,8)]
head(annotation)
# Out:
#   gene_id           gene_name
# 1 ENSG00000223972.5 DDX11L1
# 2 ENSG00000227232.5 WASH7P
# 3 ENSG00000278267.1 MIR6859-1
# 4 ENSG00000243485.5 MIR1302-2HG
# 5 ENSG00000284332.1 MIR1302-2
# 6 ENSG00000237613.2 FAM138A

# %% [markdown]
# ### create a list with the variables of each DE comparison model

# %% [markdown]
# ##### we have to remove 'Day' from Comparison_1, 'Sample_type' from Comparison 43 and 44 and
# ##### 'iPSC_line' from comparison 45 and 46. limma can't estimate the coefficients of these variables!
# ##### Probably because the its coeficients from these samples are linearly dependent of Comparison variable!
# ##### more https://support.bioconductor.org/p/111119/#111140
#
# ##### > Coefficients not estimable: Sample_typeNeuron Comparison_42wt_Neuron

# %%
#more https://support.bioconductor.org/p/111119/#111140
# comp_list[43] <- '~iPSC_line+Comparison_42'
# comp_list[44] <- '~iPSC_line+Comparison_43'
# comp_list[45] <- '~Comparison_44'
# comp_list[46] <- '~Comparison_45'

# comp_list

# %%
#for (i in 1:length(comp_list)){
#print(gsub('NA|-NA|-NA-|NA-','',paste0(unique(metadata[names(comp_list)[i]])[,1], collapse = '-')))
#    }

# %%
#comp_list <- rapply(comp_list, function(x) {gsub('No+','',x)}, how = 'list')

#comp_list <- rapply(comp_list, function(x) {gsub('^~++','~+',x)}, how = 'list')

#comp_list

# %%
#metadata_model
#samples <- metadata[colnames(metadata[14:ncol(metadata)])]
#row.names(samples)[samples[,]!='NA']

# %%
#samples$Brain_number[row.names(samples)[samples[,i]!='NA']]
#Sample_passage_mod <- as.data.frame(unclass(table(teste$DE_Analysis,teste$Passage)))
#Sample_passage_mod

# %%
#metadata[colnames(metadata[14:ncol(metadata)])]

# %%
#DEgroups <- read_xlsx('../../../Meta_sample_info/041221_SETD1A_bulk_RNAseq_Metadata.xlsx',na = 'n/a',col_names=F)

#metadata$Sample_CO <- ifelse(metadata$Sample_type == 'CO','yes','no')
#metadata$Sample_NPC  <- ifelse(metadata$Sample_type == 'NPC','yes','no')
#metadata$Sample_Neuron  <- ifelse(metadata$Sample_type == 'Neuron','yes','no')
#DEgroups <- DEgroups[,c(2,15:ncol(DEgroups))]
#colnames(DEgroups) <- DEgroups[4,]
#DEgroups <- DEgroups[-4,]

# %% [markdown]
# ### Read counts file for DE analysis

# %%
#geno_ranges <- read.delim('../../../fastq/hisat2/featurecounts_genes/count_table/_m/lengths.tsv')
#row.names(geno_ranges) <- geno_ranges$Geneid
#geno_ranges <- geno_ranges[,-1]
#head(geno_ranges)

# %%
df <- read.delim('/ceph/projects/tomoyo_SETD1A_bulk_RNA-seq/fastq/hisat2/featurecounts_genes_M/count_table/_m/counts.tsv')
#head(df)
row.names(df) <- df$Geneid
df <- df[,-1]

df <- df[row.names(metadata)]
head(df) 
dim(df)
# Out:
#                   LIBD2c1_CA137_11_CO_d12 LIBD2c1_CM130_9_CO_d12
# ENSG00000223972.5  11                       1
# ENSG00000227232.5 450                     212
# ENSG00000278267.1  22                       9
# ENSG00000243485.5   6                       1
# ENSG00000284332.1   0                       0
# ENSG00000237613.2   2                       0
#                   LIBD2c1_CM130_24_CO_d12 LIBD2c1_CM130_21_CO_d12
# ENSG00000223972.5   5                       1
# ENSG00000227232.5 235                     331
# ENSG00000278267.1   8                      19
# ENSG00000243485.5  14                       8
# ENSG00000284332.1   0                       0
# ENSG00000237613.2   0                       0
#                   LIBD7c6_CA137_37_CO_d12 LIBD7c6_CA137_109_CO_d12
# ENSG00000223972.5   0                       1
# ENSG00000227232.5 308                     235
# ENSG00000278267.1  14                      15
# ENSG00000243485.5  10                       6
# ...

# %% [markdown]
# # DE analysis

# %%
#metadata <- metadata[metadata$Sample_type == 'Cerebral_Organoid',]

# %%
#df <- df[,colnames(df) %in% row.names(metadata)]
#dim(df)
#dim(metadata)
table(colnames(df) == row.names(metadata))
# Out:
# TRUE
#   37

# %%
#convert all necessary columns into factor

var_factors <- colnames(metadata)[-c(1,2,3,5,6,9)]

metadata[var_factors] <- lapply(metadata[var_factors] , factor)

metadata$Genotype_1 <- relevel(metadata$Genotype_1,ref = 'wt')

# %% [markdown]
# ### create a SummarizedExperiment object and run the DE analysis

# %%
rse_gene <- SummarizedExperiment(list(counts=as.matrix(df)),rowData = row.names(df),colData = metadata)
#rse_gene@colData[var_factors] <- lapply(rse_gene@colData[var_factors] , factor)
rse_gene
# Out:
# class: SummarizedExperiment
# dim: 60710 37
# metadata(0):
# assays(1): counts
# rownames(60710): ENSG00000223972.5 ENSG00000227232.5 ...
#   ENSG00000278625.1 ENSG00000277374.1
# rowData names(1): X
# colnames(37): LIBD2c1_CA137_11_CO_d12 LIBD2c1_CM130_9_CO_d12 ...
#   LIBD7c6_CM130_30_Neuron_4wks LIBD7c6_CM130_78_Neuron_4wks
# colData names(59): Sample_ID New_Sample_ID ... Comparison_44
#   Comparison_45

# %%
## Hunter Checking

rowData(rse_gene)
head(assay(rse_gene))
# Out:
# DataFrame with 60710 rows and 1 column
#                                   X
#                         <character>
# ENSG00000223972.5 ENSG00000223972.5
# ENSG00000227232.5 ENSG00000227232.5
# ENSG00000278267.1 ENSG00000278267.1
# ENSG00000243485.5 ENSG00000243485.5
# ENSG00000284332.1 ENSG00000284332.1
# ...                             ...
# ENSG00000276017.1 ENSG00000276017.1
# ENSG00000278817.1 ENSG00000278817.1
# ENSG00000277196.4 ENSG00000277196.4
# ENSG00000278625.1 ENSG00000278625.1
# ENSG00000277374.1 ENSG00000277374.1
#                   LIBD2c1_CA137_11_CO_d12 LIBD2c1_CM130_9_CO_d12
# ENSG00000223972.5  11                       1
# ENSG00000227232.5 450                     212
# ENSG00000278267.1  22                       9
# ENSG00000243485.5   6                       1
# ENSG00000284332.1   0                       0
# ENSG00000237613.2   2                       0
#                   LIBD2c1_CM130_24_CO_d12 LIBD2c1_CM130_21_CO_d12
# ...

# %%
dim(metadata_full_comp)
metadata_full_comp
# Out:
# [1]  2 16
#   DE_Analysis   Sample_ID                    New_Sample_ID
# 1 Comparison_31 LIBD7c6_CM130_78_NPC         LIBD7c6_CM130_#78_NPC
# 8 Comparison_40 LIBD7c6_CM130_78_Neuron_4wks LIBD7c6_CM130_#78_Neuron_4wks
#   Brain_number iPSC_line iPSC_clone RIN  Sample_type Day Passage
# 1 Br5287       LIBD7c6   CM130_#78  10.0 NPC         0   4
# 8 Br5287       LIBD7c6   CM130_#78   9.2 Neuron      0   5
#   Patient_mutation Genotype_1 Genotype_2 Genotype_3 design
# 1 NA               wt         wt         wt         ~iPSC_line+Comparison_31
# 8 NA               wt         wt         wt         ~iPSC_line+Comparison_40
#   design2
# 1 ~iPSC_line+Genotype_1
# 8 ~iPSC_line+Genotype_1

# %%
#metadata_full_comp$design2[i]

# %%
comps <- metadata_full_comp$DE_Analysis
comps
# Out:
# [1] "Comparison_31" "Comparison_40"

# %%
for (i in 1:nrow(metadata_full_comp)){ 

    feature = metadata_full_comp$DE_Analysis[i] #Sets feature as one of the comparisons
   # dir.create(feature) #Creates a new folder, one for each of the comparisons
    
    print(feature) #Print out the name "Comparison 31" or "Comparison 40"
    keepIndex = metadata_full[metadata_full$DE_Analysis == comps[i],]$Sample_ID # select only the specific samples from each comparison #Makes index vector to keep
    rse_gene2 = rse_gene[,keepIndex] #Subsets the SE object with all the read data by the keepIndex vector
    rse_gene2@colData[var_factors] <- lapply(rse_gene2@colData[var_factors] , factor) #relevel everything
    dds <- DESeqDataSet(rse_gene2, design = formula(paste0(metadata_full_comp$design2[i]))) #Creates DESeq object using the design ~IPSC line + Genotype_1
    keep <- rowSums(counts(dds)) >= 5 #Creates vector to remove low expressed transcripts #Any gene with less than 5 counts across all samples is removed
    
    dds <- estimateSizeFactors(dds) #Calculates the median expression of each gene. Why is this done before removing
    dds <- dds[keep,] #Use the vector to remove the lowly expressed genes
    dds <- DESeq(dds) #Actually run the DESeq analysis

      #res <- results(dds, contrast = c('Disease_Status','healthy','patient'))
    res <- lfcShrink(dds, coef=paste0(resultsNames(dds)[length(resultsNames(dds))]),type='apeglm') #Changes the results to a logfold-2 change analysis
    idx <- match(row.names(res) , annotation$gene_id) #The next section is adding the gene names to the res object
    res$hgcn_symbol <- annotation$gene_name[idx]
    res$version <- paste0(feature)
    res$design <- paste0(metadata_full$design2[i])

    print(feature)
#     print(metadata_full$design[i])
#     print(table(dds$Disease_Status))
#     print(table(dds$Cell_line))
    
    #Printing out the results
    print(paste0(resultsNames(dds)[length(resultsNames(dds))],' - Number of features (raw pvalue): ',sum(res$pvalue < 0.05,na.rm=TRUE)))
    print(paste0(resultsNames(dds)[length(resultsNames(dds))],' - Number of features (fdr < 0.05): ',sum(res$padj < 0.05,na.rm=TRUE)))
    print(paste0(resultsNames(dds)[length(resultsNames(dds))],' - Number of features (fdr < 0.1): ',sum(res$padj < 0.1,na.rm=TRUE)))



#### save tables 
   # fwrite(as.data.frame(res),file=paste0('./',feature,'/diffExpr_full.tsv'), sep = "\t", quote=F,row.names=TRUE)
   # fwrite(subset(as.data.frame(res), padj < 0.05),file=paste0('./',feature,'/diffExpr_FDR005.tsv'), sep = "\t", quote=F,row.names=TRUE,na=TRUE)
   # fwrite(subset(as.data.frame(res), padj < 0.1),file=paste0('./',feature,'/diffExpr_FDR01.tsv'), sep = "\t", quote=F,row.names=TRUE,na=TRUE)


##DESeq2 plots  - pdf and png  
  #  plot1 <- EnhancedVolcano(res,title = '',
  #      lab = res$hgcn_symbol,
   #     x = 'log2FoldChange',
   #     y = 'pvalue',
   #     subtitle = '',
   #     gridlines.major = FALSE,
   #     gridlines.minor = FALSE)


    #plot2 <- DESeq2::plotMA(dds)
    
    #plot3 <- plotDispEsts(dds)


#Saving volcano plots and sparcity estimation plots to files in the copmarison folder
    
  #  pdf(paste0('./',feature,'/volcano_ma.pdf'))
  #  print(plot1)
  #  DESeq2::plotMA(dds)   
  #  dev.off()
    
        

  #  pdf(paste0('./',feature,'/deseq2qc_sparcity_est.pdf'))
  #  plotDispEsts(dds)
  #  dev.off()
    
  #  png(paste0('./',feature,'/volcano_ma1.png'),width = 8,height = 6,units = 'in',res=200)
   #  print(plot1)
   # dev.off()

   # png(paste0('./',feature,'/volcano_ma2.png'),width = 8,height = 6,units = 'in',res=200)
   # DESeq2::plotMA(dds)
   # dev.off()

   # png(paste0('./',feature,'/deseq2qc_sparcity_est.png'),width = 8,height = 6,units = 'in',res=200)
   # plotDispEsts(dds)
   # dev.off()
    
    
  #  write.table(NULL,file = paste0('./',feature,'/',metadata_full$design2[i]))#write a empty file with the design used in the comparisons
        
    if (i==1){
        comp_31 <- res
    } else {
        comp_40 <- res
    }



}
# Out:
# [1] "Comparison_31"
# using pre-existing size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# using 'apeglm' for LFC shrinkage. If used in published research, please cite:
#     Zhu, A., Ibrahim, J.G., Love, M.I. (2018) Heavy-tailed prior distributions for
#     sequence count data: removing the noise and preserving large differences.
#     Bioinformatics. https://doi.org/10.1093/bioinformatics/bty895
# [1] "Comparison_31"
# [1] "Genotype_1_mut_vs_wt - Number of features (raw pvalue): 2531"
# [1] "Genotype_1_mut_vs_wt - Number of features (fdr < 0.05): 432"
# [1] "Genotype_1_mut_vs_wt - Number of features (fdr < 0.1): 713"
# [1] "Comparison_40"
# using pre-existing size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# ...

# %%
##Insertion by Hunter: Testing the number of features for my DDS objects to compare
print("Hunter Comparison 31")
print(paste0(resultsNames(dds31)[length(resultsNames(dds31))],' - Number of features (raw pvalue): ',sum(res31$pvalue < 0.05,na.rm=TRUE)))
print(paste0(resultsNames(dds31)[length(resultsNames(dds31))],' - Number of features (fdr < 0.05): ',sum(res31$padj < 0.05,na.rm=TRUE)))
print(paste0(resultsNames(dds31)[length(resultsNames(dds31))],' - Number of features (fdr < 0.1): ',sum(res31$padj < 0.1,na.rm=TRUE)))

print("Hunter Comparison 40")
print(paste0(resultsNames(dds40)[length(resultsNames(dds40))],' - Number of features (raw pvalue): ',sum(res40$pvalue < 0.05,na.rm=TRUE)))
print(paste0(resultsNames(dds40)[length(resultsNames(dds40))],' - Number of features (fdr < 0.05): ',sum(res40$padj < 0.05,na.rm=TRUE)))
print(paste0(resultsNames(dds40)[length(resultsNames(dds40))],' - Number of features (fdr < 0.1): ',sum(res40$padj < 0.1,na.rm=TRUE)))
# Out:
# [1] "Hunter Comparison 31"
# [1] "Genotype_1_mut_vs_wt - Number of features (raw pvalue): 2531"
# [1] "Genotype_1_mut_vs_wt - Number of features (fdr < 0.05): 432"
# [1] "Genotype_1_mut_vs_wt - Number of features (fdr < 0.1): 713"
# [1] "Hunter Comparison 40"
# [1] "Genotype_1_mut_vs_wt - Number of features (raw pvalue): 1355"
# [1] "Genotype_1_mut_vs_wt - Number of features (fdr < 0.05): 37"
# [1] "Genotype_1_mut_vs_wt - Number of features (fdr < 0.1): 72"

# %%
#Those don't match up with Arthur's values...

# %% [markdown]
# ## create a df spreadsheet for the enrichment analysis in python (goatools)

# %%
# files <- Sys.glob('../_m/*/diffExpr_FDR005.tsv')
# files



# df = data.frame()

# for (i in 1:length(files)){
# genes <- read.delim(files[i])
# #genes <- genes[,c(1,8,9)]
# #names(genes)[1:2] <- c('Genes','Version')
# #genes$Version <- br_region[i]
# df = rbind(df,genes)
# }
# df$Version <- paste0('default_sizefact')
# colnames(df)[c(1,8)] <- c('genes','Comparison')
# #df <- df[,c(1,2,4,3)]
# head(df)

# fwrite(df,'fdr005_enrichment_goatools_input.tsv',sep='\t',quote=F,row.names=F)



# files <- Sys.glob('../_m/*/diffExpr_FDR01.tsv')
# files



# df = data.frame()

# for (i in 1:length(files)){
# genes <- read.delim(files[i])
# #genes <- genes[,c(1,8,9)]
# #names(genes)[1:2] <- c('Genes','Version')
# #genes$Version <- br_region[i]
# df = rbind(df,genes)
# }
# df$Version <- paste0('default_sizefact')
# colnames(df)[c(1,8)] <- c('genes','Comparison')
# #df <- df[,c(1,2,4,3)]
# head(df)

# fwrite(df,'fdr01_enrichment_goatools_input.tsv',sep='\t',quote=F,row.names=F)

# %% [markdown]
# # Repreducibility Information

# %%
dev.off()
Sys.time()
proc.time()
sessioninfo::session_info()
# Out:
# null device
#           1
# [1] "2022-11-18 12:08:24 EST"
#    user  system elapsed
# 143.306   2.648 213.393
# - Session info ---------------------------------------------------------------
#  setting  value
#  version  R version 4.1.3 (2022-03-10)
#  os       Arch Linux
#  system   x86_64, linux-gnu
#  ui       X11
#  language (EN)
#  collate  C
#  ctype    C
#  tz       America/New_York
#  date     2022-11-18
#  pandoc   2.17.0.1 @ /usr/bin/pandoc
#
# - Packages -------------------------------------------------------------------
#  package              * version    date (UTC) lib source
#  annotate               1.72.0     2021-10-26 [1] Bioconductor
#  AnnotationDbi        * 1.56.2     2021-11-09 [1] Bioconductor
#  AnnotationFilter       1.18.0     2021-10-26 [1] Bioconductor
#  AnnotationForge        1.36.0     2021-10-26 [1] Bioconductor
#  apeglm               * 1.16.0     2021-10-26 [1] Bioconductor
#  ash                    1.0-15     2015-09-01 [1] CRAN (R 4.1.3)
# ...

# %% [markdown]
# ## Comparison of Arthur's results and Hunter's results

# %%
#Now I have 4 objects, the res31 and res40 (Hunter's analysis) and the comp_31 and comp_40 from Arthur's analysis.

# %%
#head(comp_31)
#head(comp_40)

# %%
#log2changes$gene <- rownames(log2changes)
#head(log2changes)

res31$gene <- rownames(res31)
head(res31)
res40$gene <- rownames(res40)
head(res40)
# Out:
# log2 fold change (MAP): Genotype 1 mut vs wt
# Wald test p-value: Genotype 1 mut vs wt
# DataFrame with 6 rows and 6 columns
#                     baseMean log2FoldChange     lfcSE    pvalue      padj
#                    <numeric>      <numeric> <numeric> <numeric> <numeric>
# ENSG00000223972.5   0.666747   -0.000403197  0.131525  0.937795        NA
# ENSG00000227232.5 250.022350    0.010532665  0.113555  0.858296  0.983470
# ENSG00000278267.1  13.602313   -0.004097647  0.128865  0.876877  0.986916
# ENSG00000243485.5   4.140557    0.012959702  0.131424  0.461066        NA
# ENSG00000238009.6   2.881767   -0.005903300  0.130944  0.709494        NA
# ENSG00000268903.1   4.485426    0.006169666  0.130754  0.716373        NA
#                                gene
#                         <character>
# ENSG00000223972.5 ENSG00000223972.5
# ENSG00000227232.5 ENSG00000227232.5
# ENSG00000278267.1 ENSG00000278267.1
# ENSG00000243485.5 ENSG00000243485.5
# ...

# %%
comp_31$gene <- rownames(comp_31)
comp_40$gene <- rownames(comp_40)
head(comp_31)
head(comp_40)
# Out:
# log2 fold change (MAP): Genotype 1 mut vs wt
# Wald test p-value: Genotype 1 mut vs wt
# DataFrame with 6 rows and 9 columns
#                     baseMean log2FoldChange     lfcSE    pvalue      padj
#                    <numeric>      <numeric> <numeric> <numeric> <numeric>
# ENSG00000223972.5   0.666747   -0.000403197  0.131525  0.937795        NA
# ENSG00000227232.5 250.022350    0.010532663  0.113555  0.858296  0.983470
# ENSG00000278267.1  13.602313   -0.004097646  0.128865  0.876877  0.986916
# ENSG00000243485.5   4.140557    0.012959700  0.131424  0.461066        NA
# ENSG00000238009.6   2.881767   -0.005903312  0.130944  0.709494        NA
# ENSG00000268903.1   4.485426    0.006169665  0.130754  0.716373        NA
#                   hgcn_symbol       version                design
#                   <character>   <character>           <character>
# ENSG00000223972.5     DDX11L1 Comparison_31 ~iPSC_line+Genotype_1
# ...

# %%
#plotting_data_1 <- merge(as.data.frame(log2changes[c('log2FoldChange', 'pvalue')]), as.data.frame(comp_31[c('log2FoldChange', 'pvalue')]), by='row.names' )
#head(plotting_data_1)
#This is just the first merge

# %%
#as.data.frame(res31[c('log2FoldChange', 'pvalue')]) %>% nrow()
#as.data.frame(comp_31[c('log2FoldChange', 'pvalue')]) %>% nrow()

# %%
#I'm not sure why the numbers of genes in these two analyses are different from each other. I'll check the Comparison 40 as well
#as.data.frame(res40[c('log2FoldChange', 'pvalue')]) %>% nrow()
#as.data.frame(comp_40[c('log2FoldChange', 'pvalue')]) %>% nrow()

#These are also different by a couple thousand genes

# %%
#First attempt to combine
#test_comparison_31_similarity <- merge(as.data.frame(res31[c('log2FoldChange', 'pvalue')]), as.data.frame(comp_31[c('log2FoldChange', 'pvalue')]), by = 'row.names')
#head(test_comparison_31_similarity)

#Second attempt to combine. I think previously the join function hasn't worked because nearly all the column names are the same, so I'll change my column names and then use dplyr to join

alterName <- function(i){
        paste0(i, "_H")
}

colnames(res31) <- sapply(colnames(res31), alterName)
colnames(res40) <- sapply(colnames(res40), alterName)

colnames(res31)
colnames(res40)
# Out:
# [1] "baseMean_H"       "log2FoldChange_H" "lfcSE_H"          "pvalue_H"
# [5] "padj_H"           "gene_H"
# [1] "baseMean_H"       "log2FoldChange_H" "lfcSE_H"          "pvalue_H"
# [5] "padj_H"           "gene_H"

# %%
colnames(res31)[6] <- "gene"
colnames(res31)

colnames(res40)[6] <- "gene"
colnames(res40)
# Out:
# [1] "baseMean_H"       "log2FoldChange_H" "lfcSE_H"          "pvalue_H"
# [5] "padj_H"           "gene"
# [1] "baseMean_H"       "log2FoldChange_H" "lfcSE_H"          "pvalue_H"
# [5] "padj_H"           "gene"

# %%
combined_31_data <- full_join(as.data.frame(comp_31), as.data.frame(res31), by = "gene")
head(combined_31_data)

combined_40_data <- full_join(as.data.frame(comp_40), as.data.frame(res40), by = "gene")
head(combined_31_data)
# Out:
#   baseMean    log2FoldChange lfcSE     pvalue    padj      hgcn_symbol
# 1   0.6667473 -0.0004031967  0.1315247 0.9377949        NA DDX11L1
# 2 250.0223499  0.0105326633  0.1135547 0.8582965 0.9834697 WASH7P
# 3  13.6023126 -0.0040976463  0.1288652 0.8768772 0.9869159 MIR6859-1
# 4   4.1405568  0.0129597000  0.1314238 0.4610655        NA MIR1302-2HG
# 5   2.8817667 -0.0059033116  0.1309445 0.7094939        NA AL627309.1
# 6   4.4854256  0.0061696649  0.1307541 0.7163729        NA AL627309.6
#   version       design                gene              baseMean_H
# 1 Comparison_31 ~iPSC_line+Genotype_1 ENSG00000223972.5   0.6667473
# 2 Comparison_31 ~iPSC_line+Genotype_1 ENSG00000227232.5 250.0223499
# 3 Comparison_31 ~iPSC_line+Genotype_1 ENSG00000278267.1  13.6023126
# 4 Comparison_31 ~iPSC_line+Genotype_1 ENSG00000243485.5   4.1405568
# 5 Comparison_31 ~iPSC_line+Genotype_1 ENSG00000238009.6   2.8817667
# 6 Comparison_31 ~iPSC_line+Genotype_1 ENSG00000268903.1   4.4854256
# ...

# %%
#plotting_data_1 <- merge(as.data.frame(log2changes[c('log2FoldChange', 'pvalue')]), as.data.frame(comp_31[c('log2FoldChange', 'pvalue')]), by = 'row.names')

# %%
ggplot(combined_31_data, aes(x = log2FoldChange, y = log2FoldChange_H)) +
    geom_point(na.rm = TRUE) + labs(title="Arthur (x) vs Hunter (y) Comparison 31 log2FoldChanges") +
    theme_classic()

ggplot(combined_31_data, aes(x = pvalue, y = pvalue_H)) +
    geom_point(na.rm = TRUE) + labs(title="Arthur (x) vs Hunter (y) Comparison 31 pvalues") +
    theme_classic()

ggplot(combined_31_data, aes(x = padj, y = padj_H)) +
    geom_point(na.rm = TRUE) + labs(title="Arthur (x) vs Hunter (y) Comparison 31 Adjusted pvalues") +
    theme_classic()
# Out:
# plot without title
# plot without title
# plot without title

# %%
ggplot(combined_40_data, aes(x = log2FoldChange, y = log2FoldChange_H)) +
    geom_point(na.rm = TRUE) + labs(title="Arthur (x) vs Hunter (y) Comparison 40 log2FoldChanges") +
    theme_classic()

ggplot(combined_40_data, aes(x = pvalue, y = pvalue_H)) +
    geom_point(na.rm = TRUE) + labs(title="Arthur (x) vs Hunter (y) Comparison 40 pvalues") +
    theme_classic()

ggplot(combined_40_data, aes(x = padj, y = padj_H)) +
    geom_point(na.rm = TRUE) + labs(title="Arthur (x) vs Hunter (y) Comparison 40 Adjusted pvalues") +
    theme_classic()
# Out:
# plot without title
# plot without title
# plot without title

# %%
identical(combined_40_data$baseMean, combined_40_data$baseMean_H)
identical(combined_40_data$pvalue, combined_40_data$pvalue_H)
identical(combined_40_data$padj, combined_40_data$padj_H)
# Out:
# [1] TRUE
# [1] FALSE
# [1] FALSE

# %%
#There are some slight differences in the pvalues, but the baseMean values are identical for the two datasets

# %% [markdown]
# # Venn Diagram Comparisons

# %% [markdown]
# ## Comparison 31 Analysis

# %% [markdown]
# ### p-value Cutoff

# %%
#head(combined_31_data)

# %%
#Subset based on p-values

tokeep_0.05p <- combined_31_data$pvalue < 0.05
#head(tokeep_0.5p)
Arthur_0.05p <- combined_31_data$hgcn_symbol[tokeep_0.05p]
#head(Arthur_0.5p)

# %%
#head(dplyr::filter(combined_31_data, pvalue < 0.05))

# %%
tokeep_0.05pH <- combined_31_data$pvalue_H < 0.05
Hunter_0.05p <- combined_31_data$hgcn_symbol[tokeep_0.05pH]

# %%
#Created combined data object

p_value_0.05cutoff_comparison_31 <- list(Arthur = Arthur_0.05p, Hunter = Hunter_0.05p)

# %%
ggvenn(p_value_0.05cutoff_comparison_31)
# Out:
# plot without title

# %% [markdown]
# ### Adjusted p-value Cutoff

# %%
tokeep_0.05padj <- combined_31_data$padj < 0.05
Arthur_0.05padj <- combined_31_data$hgcn_symbol[tokeep_0.05padj]

tokeep_0.05padjH <- combined_31_data$padj_H < 0.05
Hunter_0.05padj <- combined_31_data$hgcn_symbol[tokeep_0.05padjH]

pAdjusted_0.05_Cutoff_Comparison_31 <- list(Arthur = Arthur_0.05padj, Hunter = Hunter_0.05padj)
ggvenn(pAdjusted_0.05_Cutoff_Comparison_31)
# Out:
# plot without title

# %%
tokeep_0.01padj <- combined_31_data$padj < 0.01
Arthur_0.01padj <- combined_31_data$hgcn_symbol[tokeep_0.01padj]

tokeep_0.01padjH <- combined_31_data$padj_H < 0.01
Hunter_0.01padj <- combined_31_data$hgcn_symbol[tokeep_0.01padjH]

pAdjusted_0.01_Cutoff_Comparison_31 <- list(Arthur = Arthur_0.01padj, Hunter = Hunter_0.01padj)
ggvenn(pAdjusted_0.01_Cutoff_Comparison_31)
# Out:
# plot without title

# %% [markdown]
# ## Comparison 40 Analysis

# %% [markdown]
# ### p-value Cutoff

# %%
tokeep_0.05p40 <- combined_40_data$pvalue < 0.05
Arthur_0.05p40 <- combined_40_data$hgcn_symbol[tokeep_0.05p40]

tokeep_0.05pH40 <- combined_40_data$pvalue < 0.05
Hunter_0.05p40 <- combined_40_data$hgcn_symbol[tokeep_0.05pH40]

pValue_0.05_Cutoff_Comparison_40 <- list(Arthur = Arthur_0.05p40, Hunter = Hunter_0.05p40)
ggvenn(pValue_0.05_Cutoff_Comparison_40)
# Out:
# plot without title

# %% [markdown]
# ### Adjusted p-value Cutoff

# %%
tokeep_0.05padj40 <- combined_40_data$padj < 0.05
Arthur_0.05padj40 <- combined_40_data$hgcn_symbol[tokeep_0.05padj40]

tokeep_0.05padjH40 <- combined_40_data$padj < 0.05
Hunter_0.05padj40 <- combined_40_data$hgcn_symbol[tokeep_0.05padjH40]

Adjusted_pValue_0.05_Cutoff_Comparison_40 <- list(Arthur = Arthur_0.05padj40, Hunter = Hunter_0.05padj40)
ggvenn(Adjusted_pValue_0.05_Cutoff_Comparison_40)
# Out:
# plot without title

# %%
tokeep_0.01padj40 <- combined_40_data$padj < 0.01
Arthur_0.01padj40 <- combined_40_data$hgcn_symbol[tokeep_0.01padj40]

tokeep_0.01padjH40 <- combined_40_data$padj < 0.01
Hunter_0.01padj40 <- combined_40_data$hgcn_symbol[tokeep_0.01padjH40]

Adjusted_pValue_0.01_Cutoff_Comparison_40 <- list(Arthur = Arthur_0.01padj40, Hunter = Hunter_0.01padj40)
ggvenn(Adjusted_pValue_0.01_Cutoff_Comparison_40)
# Out:
# plot without title

# %%
## So all of the genes came out exactly the same. This makes sense because I was trying to do exactly what Arthur had done, so this was successful.

# %% [markdown]
# ## Adjusted vs non-adjusted pvalue overlap

# %%
# Starting with Comparison 31

p_values_to_keep <- combined_31_data$pvalue < 0.05
p_value_genes <- combined_31_data$hgcn_symbol[p_values_to_keep]

p_adj_to_keep <- combined_31_data$padj < 0.05
p_adj_genes <- combined_31_data$hgcn_symbol[p_adj_to_keep]

comp <- list(pvalue = p_value_genes, padj = p_adj_genes)
print("Comparison 31 p-value vs adjusted p-value genes")
ggvenn(comp)

p_values_to_keep_40 <- combined_40_data$pvalue < 0.05
p_value_genes_40 <- combined_40_data$hgcn_symbol[p_values_to_keep_40]

p_adj_to_keep_40 <- combined_40_data$padj < 0.05
p_adj_genes_40 <- combined_40_data$hgcn_symbol[p_adj_to_keep_40]

comp_40 <- list(pvalue = p_value_genes_40, padj = p_adj_genes_40)
print("Comparison 40 p-value vs adjusted p-value genes")
ggvenn(comp_40)
# Out:
# [1] "Comparison 31 p-value vs adjusted p-value genes"
# [1] "Comparison 40 p-value vs adjusted p-value genes"
# plot without title
# plot without title
